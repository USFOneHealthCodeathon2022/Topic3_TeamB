# %%
# %matplotlib inline

# %% [markdown]
# # Tutorial 02: Words Analysis
#
# Analyzing collected text data and metadata.

# %% [markdown]
# ## Words Analyses
#
# This tutorial covers exploring & analyzing words data.
#
# For this tutorial, we will reload and use the :class:`~.Words` object with
# the data that we collected in the last tutorial.
#
# Note that this tutorial requires some optional dependencies, including the
# `WordCloud <https://github.com/amueller/word_cloud>`_ module.

# %%
# Import the custom objects that are used to store collected words data
from lisc.data import Articles, ArticlesAll

# Import database and IO utilities to reload our previously collected data
from lisc.utils.db import SCDB
from lisc.utils.io import load_object

# Import plots that are available for words data
from lisc.plts.words import plot_wordcloud

import scispacy
import spacy
nlp = spacy.load("en_ner_bionlp13cg_md")

# %% [markdown]
# ### Articles Object
#
# LISC uses custom objects to store and organize collected words data.
#
# These objects are used internally in the :class:`~.Words` objects.
#
# If the data collection was set to save out data as it was collected, then
# :obj:`~.Articles` objects can be loaded individually, using the label
# of the search term.

# %%
# Set up database object
db = SCDB('lisc_db')

# Load raw data for a particular term
term = 'whipworm'

arts = Articles(term)
arts.load(db)

# %% [markdown]
# ### ArticlesAll Object
#
# The :obj:`~.ArticlesAll` object aggregates collected data across all articles collected
# for a given search term.

# %%
# Collapse data across articles
arts_all = ArticlesAll(arts)

# %% [markdown]
# It also has methods to create and check summaries created from the aggregate data.

# %%
# Check an example summary
arts_all.create_summary()
arts_all.print_summary()
# Out:
# whipworm :
#   Number of articles: 		 99
#   First publication: 		 2017
#   Most common author: 		 Keiser J
#     number of publications: 	 6
#   Most common journal: 		 PLoS neglected tropical diseases
#     number of publications: 	 6

# %% [markdown]
# ### Words Object
#
# The :class:`~.Words` object can also be used to reload and analyze collected data.
#
# The `results` attribute contains a list of :class:`~.Articles` objects, one for each term.

# %%
# Reload the words object, specifying to also reload the article data
words = load_object('tutorial_words', directory=SCDB('lisc_db'), reload_results=True)

# %% [markdown]
# Note that the reloaded data is the raw data from the data collection.
#
# The :meth:`~.Words.process_articles` method can be used to do some preprocessing on the
# collected data.
#
# By default, the :func:`~.process_articles` function is used to process articles, which
# preprocesses journal and author names, and tokenizes the text data. You can also pass in
# a custom function to apply custom processing to the collected articles data.
#
# Note that some processing steps, like converting to the ArticlesAll representation,
# will automatically apply article preprocessing.

# %%
# Preprocess article data
words.process_articles()

# %% [markdown]
# We can also aggregate data across articles, just as we did before, directly in the Words object.
#
# If you run the :meth:`~.Words.process_combined_results` method, then the
# `combined_results` attribute will contain the corresponding list of
# :class:`~.ArticlesAll` objects, also one for each term.

# %%
# Process collected data into aggregated data objects
words.process_combined_results()

# %%
# doc = nlp("gut")

# for token in doc:
#     print(token.text, token.pos_, token.ent_type_, token.head.text)

symptoms_list = ['microbiome', 'microbiota', 'gut', 'microbial', 'metabolites', 'anemia',  
                 'intestinal', 'obstruction',  'growth', 'faltering',  
                 'abdominal', 'pain', 'vomiting', 'cholangitis', 
                 'pancreatitis', 'anorexia', 'weight',  'gall', 'bladder', 'cancer', 'gallbladder',  
                 'cough',  'developmental', 'delay', 'hyperactivity']


term_list = ["roundworm", "whipworm", "hookworms"]

# %%
for num in range(0,3):
    print("-------", term_list[num],"-------")
    for i in words.combined_results[num].words:
        doc = nlp(i)
        for token in doc:
            if(token.pos_ == "NOUN" or token.pos_ == "ADJ"):
                if(words.combined_results[0].words[i] > 1 and i in symptoms_list):
                    print(i, "-", words.combined_results[0].words[i], "[", token.ent_type_,"]")
                    
    print()
    print()
# Out:
# ------- roundworm -------
# intestinal - 86 [  ]
# abdominal - 14 [  ]
# pain - 15 [  ]
# obstruction - 8 [  ]
# bladder - 5 [ ORGAN ]
# gallbladder - 4 [ ORGAN ]
# microbiota - 4 [  ]
# cholangitis - 4 [  ]
# weight - 2 [  ]
# gut - 3 [ ORGANISM_SUBDIVISION ]
# metabolites - 2 [  ]
# developmental - 2 [  ]
# growth - 2 [  ]
# anorexia - 2 [  ]
# cancer - 3 [ CANCER ]
# pancreatitis - 14 [  ]
#
#
# ------- whipworm -------
# intestinal - 86 [  ]
# metabolites - 2 [  ]
# weight - 2 [  ]
# developmental - 2 [  ]
# abdominal - 14 [  ]
# gut - 3 [ ORGANISM_SUBDIVISION ]
# growth - 2 [  ]
# microbiota - 4 [  ]
# cancer - 3 [ CANCER ]
# pain - 15 [  ]
#
#
# ------- hookworms -------
# metabolites - 2 [  ]
# weight - 2 [  ]
# growth - 2 [  ]
# intestinal - 86 [  ]
# cancer - 3 [ CANCER ]
# microbiota - 4 [  ]
# gut - 3 [ ORGANISM_SUBDIVISION ]
# developmental - 2 [  ]
# abdominal - 14 [  ]

# %%
# Plot a WordCloud of the collected data for the first term
# plot_wordcloud(words.combined_results[1].words, 25)

# %% [markdown]
# ## Exploring Words Data
#
# The :class:`~.Words` object also has some methods for exploring the data, including
# allowing for indexing into and looping through collected results.

# %%
# # Index results for a specific label
# print(words['roundworm'])

# %% [markdown]
# You can also loop through all the articles found for a specified search term.
#
# The iteration returns a dictionary with all the article data, which can be examined.

# %%
# Iterating through articles found for a search term of interest
for art in words['whipworm']:
    if(art['keywords'] == []):
        continue
        
    print(art['title'])
    print(art['words'])
    print()
# Out:
# Mucosal Vaccination With Recombinant Tm-WAP49 Protein Induces Protective Humoral and Cellular Immunity Against Experimental Trichuriasis in AKR Mice.
# ['trichuriasis', 'one', 'common', 'neglected', 'tropical', 'diseases', 'worlds', 'poorest', 'people', 'recombinant', 'vaccine', 'composed', 'tm-wap49', 'immunodominant', 'antigen', 'secreted', 'adult', 'trichuris', 'stichocytes', 'mucosa', 'cecum', 'parasite', 'attaches', 'development', 'prototype', 'evaluated', 'mouse', 'model', 'trichuris', 'muris', 'infection', 'ultimate', 'goal', 'producing', 'mucosal', 'vaccine', 'intranasal', 'delivery', 'intranasal', 'immunization', 'mice', 'tm-wap49', 'formulated', 'adjuvant', 'och', 'truncated', 'analog', 'alpha-galcer', 'adjuvanticity', 'stimulate', 'natural', 'killer', 'cells', 'nkt', 'mucosal', 'immunity', 'induced', 'significantly', 'high', 'levels', 'igg', 'subclasses', 'igg1', 'igg2a', 'immunized', 'mice', 'also', 'resulted', 'significant', 'reduction', 'worm', 'burden', 'challenge', 'muris-infective', 'eggs', 'addition', 'qs-21', 'adjuvant', 'vaccine', 'formulation', 'reduced', 'worm', 'counts', 'improved', 'protection', 'dual-adjuvanted', 'vaccine', 'correlated', 'higher', 'serum', 'antibody', 'responses', 'igg', 'igg1', 'igg2a', 'iga', 'well', 'induction', 'antigen-specific', 'iga', 'nasal', 'mucosa', 'also', 'associated', 'robust', 'cellular', 'responses', 'including', 'functional', 'subsets', 'cd4', 'cells', 'producing', 'il-4', 'cytotoxic', 'cd8', 'cells', 'expressing', 'granzyme', 'b', 'worm', 'reduction', 'achieved', 'mucosal', 'immunization', 'higher', 'induced', 'subcutaneous', 'immunization', 'intranasal', 'immunization', 'also', 'induced', 'significantly', 'higher', 'nasal', 'mucosa-secreted', 'antigen-specific', 'iga', 'response', 'well', 'higher', 'functional', 'cellular', 'responses', 'including', 'cd4il4', 'th1', 'cd8gnzb', 'th2', 'cells', 'antigen-specific', 'infγ-producing', 'cells', 'spleen', 'mlns', 'antibody-producing', 'b', 'cells', 'cd19b220/b220gl7', 'mucosal', 'immunization', 'induced', 'long-term', 'lymphocyte', 'memory', 'increased', 'central', 'cd62lcd44', 'effector', 'cd62l-cd44', 'memory', 'subsets', 'cd4', 'cd8', 'cells', '60', 'days', 'last', 'immunization', 'summary', 'intranasal', 'immunization', 'recombinant', 'tm-wap49', 'protein', 'induced', 'strong', 'protection', 'versus', 'murine', 'trichuriasis', 'represents', 'promising', 'vaccination', 'approach', 'intestinal', 'nematodes']
#
# Concurrent allergy and helminthiasis in underprivileged urban South African adults previously residing in rural areas.
# ['study', 'investigated', 'whether', 'prior', 'exposure', 'helminths', 'ascaris', 'ige', 'ascaris', 'eggs', 'trichuris', 'eggs', 'either', 'childhood', 'adulthood', 'residence', 'rural', 'resource-limited', 'urban', 'areas', 'influence', 'allergy', 'outcomes', 'asthma', 'rhinitis', 'ige', 'atopy', 'food', 'allergy', 'south', 'african', 'population', 'participants', 'historical', 'present', 'allergies', 'data', 'collected', 'questionnaires', 'clinical', 'record', 'files', 'coproscopy', 'immunoassays', 'immunocaptm', 'phadiatop', 'total', 'ige', 'allergin-specific', 'fx3', 'ige', 'immunoassays', 'ascaris', 'ige', 'radioallergosorbent', 'rast', 'tests', 'used', 'active', 'helminthiasis', 'allergy', 'screens', 'respectively', 'data', 'analyzed', 'using', 'logistic', 'regression', 'analysis', 'models', 'adjusted', 'age', 'gender', 'locality', 'high', 'ascaris', 'ige', 'significantly', 'associated', 'asthma', 'aor2.20', 'p0.047', 'ige', 'atopy', 'aor18.18', 'p0.0001', 'food', 'allergy', 'aor14.47', 'p0.0001', 'asthma', 'significantly', 'less', 'likely', 'among', 'participants', 'ascaris', 'eggs', 'aor0.43', 'p0.048', 'trichuris', 'eggs', 'aor0.36', 'p0.024', 'findings', 'co-occurrent', 'helminthiasis', 'allergic', 'disorders', 'population', 'resided', 'rural', 'peri-urban', 'informal', 'settlements', 'oppose', 'agree', 'two', 'main', 'notions', 'hygiene', 'hypothesis', 'individuals', 'residing', 'rural', 'settings', 'poor', 'sanitation', 'geohelminth', 'infection', 'less', 'prone', 'allergy', 'ii', 'helminth', 'infections', 'protect', 'allergy', 'respectively', 'research', 'warranted']
#
# Bacterial communities from Trichuris spp. A contribution to deciphering the role of parasitic nematodes as vector of pathogens.
# ['microbiome', 'taxa', 'associated', 'parasitic', 'nematodes', 'unknown', 'invertebrate', 'parasites', 'could', 'act', 'reservoirs', 'vectors', 'horizontally', 'transferred', 'virulence', 'factors', 'could', 'also', 'provide', 'potential', 'pool', 'future', 'emerging', 'pathogens', 'trichuris', 'trichiura', 'trichuris', 'suis', 'geohelminths', 'parasitizing', 'caecum', 'primates', 'including', 'humans', 'pigs', 'respectively', 'present', 'work', 'preliminary', 'study', 'evaluate', 'bacterial', 'communities', 'associated', 'trichiura', 'suis', 'using', 'high', 'throughput', 'sequencing', 'checking', 'possible', 'presence', 'pathogens', 'nematodes', 'determine', 'whether', 'parasitic', 'helminths', 'act', 'vectors', 'bacterial', 'pathogens', 'human', 'animal', 'hosts', 'five', 'trichiura', 'adult', 'specimens', 'obtained', 'caecum', 'macaque', 'macaca', 'sylvanus', 'two', 'suis', 'adults', 'collected', 'caecum', 'swine', 'sus', 'scrofa', 'domestica', '16s', 'rrna', 'gene', 'hts', 'approach', 'employed', 'investigate', 'composition', 'diversity', 'bacterial', 'communities', 'trichuris', 'spp', 'special', 'emphasis', 'intestinal', 'level', 'samples', 'showed', 'rich', 'colonization', 'bacteria', 'included', 'preferently', 'phyla', 'proteobacteria', 'firmicutes', 'actinobacteria', 'bacteroidetes', 'cyanobacteria', 'verrucomicrobia', 'total', '36', 'phyla', '200', 'families', 'identified', 'samples', 'potential', 'pathogen', 'bacteria', 'detected', 'helminths', 'related', 'genera', 'bartonella', 'mycobacterium', 'rickettsia', 'salmonella', 'escherichia/shigella', 'aeromonas', 'clostridium', 'presence', 'pathogenic', 'bacteria', 'trichuris', 'spp', 'would', 'position', 'species', 'new', 'threat', 'humans', 'since', 'nematodes', 'could', 'spread', 'new', 'diseases', 'study', 'also', 'contribute', 'understanding', 'host-microbiota', 'relation']
#
# Sertraline as a new potential anthelmintic against Haemonchus contortus: toxicity, efficacy, and biotransformation.
# ['haemonchus', 'contortus', 'parasitic', 'nematode', 'ruminants', 'causes', 'significant', 'losses', 'many', 'farmers', 'worldwide', 'since', 'drugs', 'currently', 'use', 'treatment', 'haemonchosis', 'losing', 'effectiveness', 'due', 'drug-resistance', 'nematode', 'new', 'repurposed', 'drug', 'highly', 'needed', 'antipsychotic', 'drug', 'sertraline', 'srt', 'shown', 'effective', 'parasitic', 'nematodes', 'trichuris', 'muris', 'ancylostoma', 'caninum', 'schistosoma', 'mansoni', 'aim', 'present', 'study', 'evaluate', 'possible', 'effect', 'srt', 'h', 'contortus', 'potential', 'hepatotoxicity', 'srt', 'tested', 'sheep', 'common', 'h', 'contortus', 'host', 'addition', 'main', 'metabolic', 'pathways', 'srt', 'h.', 'contortus', 'ovine', 'liver', 'identified', 'effect', 'srt', 'h', 'contortus', 'egg', 'hatching', 'observed', 'srt', 'found', 'significantly', 'decrease', 'viability', 'h', 'contortus', 'adults', 'drug-sensitive', 'resistant', 'strains', 'effect', 'comparable', 'commonly', 'used', 'anthelmintics', 'levamisole', 'monepantel', 'moreover', 'srt', 'anthelmintically', 'active', 'concentrations', 'showed', 'toxicity', 'ovine', 'liver', 'biotransformation', 'srt', 'h', 'contortus', 'weak', 'drug', 'remaining', 'unmetabolized', 'production', 'main', 'metabolite', 'hydroxy-srt', 'differ', 'significantly', 'strains', 'minor', 'metabolites', 'srt-o-glucoside', 'dihydroxy-srt', 'srt-ketone', 'also', 'identified', 'h', 'contorts', 'adults', 'compared', 'h.', 'contortus', 'ovine', 'liver', 'metabolized', 'srt', 'extensively', 'mainly', 'via', 'desmethylation', 'glucuronidation', 'conclusion', 'potency', 'srt', 'h', 'contortus', 'proven', 'tested', 'toward', 'possible', 'repurposing']
#
# Significant Leukocytosis with Hypereosinophilia Secondary to Trichuris trichiura in Adult: A Case Report.
# ['eosinophilic', 'leukocytosis', 'attributed', 'number', 'clinical', 'conditions', 'parasitic', 'infection', 'allergies', 'neoplasms', 'parasitic', 'infection', 'main', 'cause', 'eosinophilia', 'however', 'marked', 'leukocytosis', 'hypereosinophilia', 'secondary', 'trichuris', 'trichiura', 'adults', 'previously', 'reported', 'describe', 'case', '39-year-old', 'man', 'presented', 'fever', 'diarrhea', 'investigation', 'revealed', 'white', 'blood', 'cell', 'wbc', 'count', '20.69', '×', '109/l', 'absolute', 'eosinophil', 'count', '12.44', '×', '109/l', 'fecal', 'microscopic', 'examination', 'demonstrated', 'trichuria', 'eggs', 'wbc', 'count', 'returned', 'normal', 'following', 'treatment', 'albendazole', 'literature', 'pertaining', 'hematological', 'findings', 'associated', 'trichuris', 'trichiura', 'explored', 'report', 'case', 'highlights', 'significant', 'elevation', 'leukocyte', 'count', 'hypereosinophilia', 'one', 'manifestations', 'trichuriasis', 'infection', 'adults', 'empirical', 'treatment', 'anti-helminthic', 'agents', 'may', 'play', 'role', 'suspected', 'cases', 'avoid', 'severe', 'complications', 'trichuris', 'dysentery', 'syndrome']
#
# Population Pharmacokinetic-Pharmacodynamic Model of Oxfendazole in Healthy Adults in a Multiple Ascending Dose and Food Effect Study and Target Attainment Analysis.
# ['oxfendazole', 'potent', 'veterinary', 'antiparasitic', 'drug', 'undergoing', 'development', 'human', 'use', 'treat', 'multiple', 'parasitic', 'infections', 'results', 'two', 'recently', 'completed', 'phase', 'clinical', 'trials', 'conducted', 'healthy', 'adults', 'showed', 'pharmacokinetics', 'oxfendazole', 'nonlinear', 'affected', 'food', 'administration', 'repeated', 'doses', 'appeared', 'mildly', 'affect', 'hemoglobin', 'concentrations', 'facilitate', 'oxfendazole', 'dose', 'optimization', 'use', 'patient', 'populations', 'relationship', 'among', 'oxfendazole', 'dose', 'pharmacokinetics', 'hemoglobin', 'concentration', 'quantitatively', 'characterized', 'using', 'population', 'pharmacokinetic-pharmacodynamic', 'modeling', 'fasting', 'subjects', 'oxfendazole', 'pharmacokinetics', 'well', 'described', 'one-compartment', 'model', 'first-order', 'absorption', 'elimination', 'change', 'oxfendazole', 'pharmacokinetics', 'administered', 'following', 'fatty', 'meal', 'captured', 'absorption', 'model', 'one', 'transit', 'compartment', 'increased', 'bioavailability', 'effect', 'oxfendazole', 'exposure', 'hemoglobin', 'concentration', 'healthy', 'adults', 'characterized', 'life', 'span', 'indirect', 'response', 'model', 'oxfendazole', 'positive', 'minor', 'inhibitory', 'effect', 'red', 'blood', 'cell', 'synthesis', 'simulation', 'indicated', 'oxfendazole', 'low', 'risk', 'posing', 'safety', 'concern', 'regarding', 'hemoglobin', 'concentration', 'even', 'high', 'oxfendazole', 'dose', '60', 'mg/kg', 'body', 'weight', 'daily', 'final', 'model', 'used', 'perform', 'comprehensive', 'target', 'attainment', 'simulations', 'whipworm', 'infection', 'filariasis', 'various', 'dose', 'regimens', 'target', 'attainment', 'criteria', 'results', 'modeling', 'work', 'adopted', 'appropriately', 'potential', 'greatly', 'facilitate', 'oxfendazole', 'dose', 'regimen', 'optimization', 'patient', 'populations', 'different', 'types', 'parasitic', 'infections']
#
# Contamination of Soil and Vegetation with Developmental Forms of Parasites in the Area of the Federation of Bosnia and Herzegovina.
# ['according', '2019', '1.5', 'billion', 'people', 'worldwide', 'infected', 'soil-transmitted', 'parasites', 'previous', 'research', 'federation', 'bosnia', 'herzegovina', 'fbh', 'mainly', 'conducted', 'area', 'sarajevo', 'canton', 'therefore', 'aim', 'research', 'explore', 'contamination', 'soil', 'vegetation', 'developmental', 'forms', 'parasites', 'cantons', 'fbh', 'apr', 'oct', '2018', 'total', '1,618', 'soil', 'vegetation', 'samples', 'taken', '386', 'different', 'locations', '9', 'cantons', 'fbh', 'positive', 'samples', 'observed', '65/66', '98.48', 'municipalities/cities', '239/386', '61.92', 'locations', '1,618', 'samples', 'taken', 'total', '1,263', 'soil', 'samples', '355', 'vegetation', 'samples', '357', '22.06', 'positive', '337', '26.68', '20', '5.63', 'soil', 'plant', 'samples', 'respectively', 'total', 'following', 'adult', 'developmental', 'forms', 'identified', 'taeniidae', 'eggs', '7.30', 'toxocara', 'spp', 'eggs', '62.08', 'ancylostomatidae', 'eggs', '25.00', 'trichuris', 'spp', 'eggs', '9.55', 'capillaria', 'spp', 'eggs', '3.37', 'toxascaris', 'leonina', 'eggs', '1.40', 'nematodes', 'larvae', '19.38', 'giardia', 'duodenalis', 'cysts', '5.06', 'cryptosporidium', 'spp', 'oocysts', '1.4', 'oocysts', 'cysts', 'different', 'species', 'protozoa', '3.93', 'identified', 'developmental', 'forms', 'parasites', 'pose', 'permanent', 'threat', 'human', 'health', 'necessary', 'carry', 'measures', 'reduce', 'contamination', 'soil', 'vegetation', 'coordination', 'systematic', 'solutions', 'legislation', 'paralelly', 'contribution', 'animal', 'owners', 'veterinarians', 'physicians', 'ecologists', 'parents', 'others', 'involved', 'issue']
#
# Host and geographic differences in prevalence and diversity of gastrointestinal helminths of foxes (Vulpes vulpes), coyotes (Canis latrans) and wolves (Canis lupus) in Québec, Canada.
# ['wild', 'canids', 'hosts', 'wide', 'range', 'parasites', 'play', 'role', 'transmission', 'zoonoses', 'many', 'parasites', 'transmitted', 'food', 'webs', 'wild', 'canids', 'high', 'trophic', 'levels', 'parasite', 'prevalence', 'diversity', 'wild', 'canids', 'serve', 'excellent', 'indicators', 'ecosystem', 'health', 'main', 'objectives', 'update', 'knowledge', 'composition', 'gastrointestinal', 'helminths', 'wild', 'canids', 'québec', 'canada', 'describe', 'differences', 'parasite', 'prevalence', 'diversity', 'among', 'canid', 'species', 'regions', 'hunters', 'trappers', 'provided', 'whole', 'carcasses', 'red', 'foxes', 'vulpes', 'vulpes', 'n', '176', 'intestinal', 'tracts', 'coyotes', 'canis', 'latrans', 'n', '77', 'gray', 'wolves', 'canis', 'lupus', 'n', '23', 'harvested', 'non-research', 'purposes', 'winter', '2016-2017', 'modified', 'stolls', 'centrifugation', 'sucrose', 'flotation', 'feces', '250', 'wild', 'canids', 'used', 'eggs', 'one', 'family', 'eight', 'genera', 'parasitic', 'helminths', 'recovered', 'diphyllobothriids', 'taenia/echinococcus', 'spp', 'capillaria', 'spp', 'toxascaris', 'sp', 'toxocara', 'sp', 'trichuris', 'sp', 'uncinaria', 'sp', 'metorchis', 'sp', 'adult', 'taenia', 'spp', 'cestodes', 'recovered', '61', '276', '22', 'canids', 'six', 'different', 'species', 'hydatigena', 'twitchelli', 'crassiceps', 'polyacantha', 'krabbei', 'pisiformis-like', 'differentiated', 'based', 'dna', 'sequenced', '65', 'individual', 'adult', 'cestodes', 'using', 'primers', 'nicotinamide', 'adenosine', 'dinucleotide', 'dehydrogenase', 'subunit', '1', 'nd1', 'cytochrome', 'c', 'oxidase', 'subunit', '1', 'co1', 'mitochondrial', 'dna', 'loci', 'alaria', 'sp', 'trematodes', 'infected', '89', '276', 'canids', '32', 'subset', 'identified', 'americana', 'co1', 'locus', 'marine', 'trematode', 'cryptocotyle', 'lingua', 'reported', 'first', 'time', 'foxes', 'province', 'québec', 'results', 'help', 'us', 'understand', 'fully', 'predator-prey', 'relationships', 'within', 'group', 'canids', 'baseline', 'data', 'regional', 'parasite', 'prevalence', 'intensity', 'critical', 'order', 'detect', 'future', 'changes', 'following', 'ecological', 'disturbances', 'due', 'climate', 'landscape', 'alterations']
#
# Linking Behavior, Co-infection Patterns, and Viral Infection Risk With the Whole Gastrointestinal Helminth Community Structure in Mastomys natalensis.
# ['infection', 'probability', 'load', 'community', 'structure', 'helminths', 'varies', 'strongly', 'within', 'animal', 'populations', 'ascribed', 'environmental', 'stochasticity', 'due', 'individual', 'characteristics', 'host', 'age', 'sex', 'understudied', 'factors', 'hosts', 'behavior', 'co-infection', 'patterns', 'study', 'used', 'multimammate', 'mouse', 'mastomys', 'natalensis', 'model', 'system', 'investigate', 'hosts', 'sex', 'age', 'exploration', 'behavior', 'viral', 'infection', 'history', 'affects', 'infection', 'risk', 'parasitic', 'load', 'community', 'structure', 'gastrointestinal', 'helminths', 'hypothesized', 'hosts', 'exploration', 'behavior', 'would', 'play', 'key', 'role', 'risk', 'infection', 'different', 'gastrointestinal', 'helminths', 'whereby', 'highly', 'explorative', 'individuals', 'would', 'higher', 'infection', 'risk', 'leading', 'wider', 'diversity', 'helminths', 'larger', 'load', 'compared', 'less', 'explorative', 'individuals', 'fieldwork', 'performed', 'morogoro', 'tanzania', 'trapped', 'total', '214', 'individual', 'mice', 'exploratory', 'behavior', 'characterized', 'using', 'hole-board', 'test', 'collected', 'helminths', 'inside', 'gastrointestinal', 'tract', 'study', 'found', 'helminths', 'belonging', 'eight', 'different', 'genera', 'hymenolepis', 'sp', 'protospirura', 'muricola', 'syphacia', 'sp', 'trichuris', 'mastomysi', 'gongylonema', 'sp', 'pterygodermatites', 'sp', 'raillietina', 'sp', 'inermicapsifer', 'sp', 'one', 'family', 'trichostrongylidae', 'hierarchical', 'modeling', 'species', 'communities', 'hmsc', 'used', 'investigate', 'effect', 'different', 'host-related', 'factors', 'infection', 'probability', 'parasite', 'load', 'community', 'structure', 'helminths', 'results', 'show', 'species', 'richness', 'higher', 'adults', 'females', 'compared', 'juveniles', 'males', 'respectively', 'contrary', 'expectations', 'found', 'less', 'explorative', 'individuals', 'higher', 'infection', 'probability', 'different', 'helminths', 'resulting', 'higher', 'diversity', 'could', 'due', 'higher', 'exposure', 'rate', 'helminths', 'and/or', 'behavioral', 'modification', 'due', 'infection']
#
# Safety and tolerability of medicinal parasite ova (Trichuris suis) in healthy Japanese volunteers: A randomized, double-blind, placebo-controlled trial.
# ['trichuris', 'suis', 'ova', 'tso', 'potential', 'modulate', 'human', 'immune', 'system', 'tested', 'therapeutic', 'application', 'autoimmune', 'allergic', 'diseases', 'inflammatory', 'bowel', 'disease', 'ibd', 'previous', 'clinical', 'studies', 'limited', 'european', 'american', 'participants', 'whereas', 'asian', 'populations', 'well', 'documented', 'study', 'clinical', 'trial', 'conducted', 'examine', 'safety', 'tolerability', 'tso', 'administration', 'among', 'healthy', 'japanese', 'population', 'study', 'randomized', 'double-blind', 'placebo-controlled', 'trial', 'held', 'jikei', 'university', 'hospital', 'tokyo', 'twelve', 'volunteers', 'stratified', 'three', 'groups', 'receiving', 'different', 'doses', 'tso', 'tso', '1000', '2500', '7500', 'another', 'control', 'group', 'cases', 'limited', 'healthy', 'japanese', 'men', 'aged', '20', 'years', 'old', 'single', 'doses', 'medicinal', 'tso', 'placebo', 'given', 'three', 'participants', 'group', 'participants', 'followed', '56', 'days', 'ingestion', 'follow-up', 'period', 'clinical', 'practitioners', 'checked', 'participant', 'clinic', '7', '14', '28', '56', 'days', 'post-ingestion', 'dpi', 'clinical', 'symptoms', 'evaluated', 'using', 'questionnaire-based', 'self-reporting', 'participants', 'filled', 'every', 'visit', 'blood', 'samples', 'drawn', '7', '14', '28', '56', 'dpi', 'fecal', 'samples', 'collected', '28', '56', 'dpi', 'study', 'period', 'twelve', 'healthy', 'japanese', 'male', 'volunteers', 'enrolled', 'participants', 'completed', 'follow-up', 'period', 'severe', 'adverse', 'events', 'observed', 'study', 'period', 'groups', 'three', 'participants', 'tso', '1000', '2500', '7500', 'groups', 'mild', 'moderate', 'abdominal', 'symptoms', 'diarrhea', 'bloating', 'appetite', 'loss', 'observation', 'period', 'one', 'participant', 'placebo', 'group', 'presented', 'mild', 'diarrhea', 'microscopic', 'examination', 'identified', 'parasite', 'ova', 'fecal', 'samples', 'blood', 'sample', 'examination', 'indicated', 'elevated', 'eosinophil', 'count', 'several', 'cases', 'especially', 'groups', 'higher', 'dose', 'tso', 'extra-abdominal', 'symptoms', 'present', 'cases', 'healthy', 'japanese', 'people', 'tolerated', 'doses', 'tso', 'without', 'severe', 'adverse', 'events', 'hand', 'mild', 'moderate', 'abdominal', 'symptoms', 'observed', 'several', 'participants', 'study', 'suggested', 'medicinal', 'use', 'tso', 'japan', 'relatively', 'safe', 'close', 'follow-up', 'recommended', 'sustainable', 'usage']
#
# Effect of co-infection with intestinal parasites on COVID-19 severity: A prospective observational cohort study.
# ['background', 'severe', 'acute', 'respiratory', 'syndrome', 'coronavirus', '2', 'sars-cov-2', 'infection', 'results', 'spectrum', 'clinical', 'presentations', 'evidence', 'africa', 'indicates', 'significantly', 'less', 'covid-19', 'patients', 'suffer', 'serious', 'symptoms', 'industrialized', 'world', 'others', 'previously', 'postulated', 'partial', 'explanation', 'phenomenon', 'different', 'activated', 'immune', 'system', 'due', 'parasite', 'infections', 'aimed', 'test', 'hypothesis', 'investigating', 'potential', 'correlation', 'co-infection', 'parasites', 'covid-19', 'severity', 'endemic', 'area', 'africa', 'methods', 'ethiopian', 'covid-19', 'patients', 'enrolled', 'screened', 'intestinal', 'parasites', 'july', '2020', 'march', '2021', 'primary', 'outcome', 'proportion', 'patients', 'severe', 'covid-19', 'ordinal', 'logistic', 'regression', 'models', 'used', 'estimate', 'association', 'parasite', 'infection', 'covid-19', 'severity', 'models', 'adjusted', 'sex', 'age', 'residence', 'education', 'level', 'occupation', 'body', 'mass', 'index', 'comorbidities', 'findings', '751', 'sars-cov-2', 'infected', 'patients', 'enrolled', '284', '37.8', 'intestinal', 'parasitic', 'infection', '27/255', '10.6', 'severe', 'covid-19', 'patients', 'co-infected', 'intestinal', 'parasites', '257/496', '51.8', 'non-severe', 'covid-19', 'patients', 'parasite', 'positive', 'p0.0001', 'patients', 'co-infected', 'parasites', 'lower', 'odds', 'developing', 'severe', 'covid-19', 'adjusted', 'odds', 'ratio', 'aor', '0.23', '95', 'ci', '0.17-0.30', 'p0.0001', 'parasites', 'aor', '0.37', '95', 'ci', '0.26-0.51', 'p0.0001', 'protozoa', 'aor', '0.26', '95', 'ci', '0.19-0.35', 'p0.0001', 'helminths', 'stratified', 'species', 'co-infection', 'entamoeba', 'spp', 'hymenolepis', 'nana', 'schistosoma', 'mansoni', 'trichuris', 'trichiura', 'implied', 'lower', 'probability', 'developing', 'severe', 'covid-19', '11', 'deaths', '1.5', 'among', 'patients', 'without', 'parasites', 'p', '0.009', 'interpretation', 'parasite', 'co-infection', 'associated', 'reduced', 'risk', 'severe', 'covid-19', 'african', 'patients', 'parasite-driven', 'immunomodulatory', 'responses', 'may', 'mute', 'hyper-inflammation', 'associated', 'severe', 'covid-19', 'funding', 'european', 'developing', 'countries', 'clinical', 'trials', 'partnership', 'edctp', '-', 'european', 'union', 'joep', 'lange', 'institute', 'jli', 'netherlands', 'trial', 'registration', 'clinicaltrials.gov', 'nct04473365']
#
# Etiology of Colitis-Complex Diarrhea in Growing Pigs: A Review.
# ['colitis-complex', 'diarrhea', 'ccd', 'pigs', 'defined', 'type', 'diarrhea', 'associated', 'colonic', 'inflammation', 'disrupted', 'colonic', 'gut', 'barrier', 'functionality', 'growing', 'pigs', '4-16', 'weeks', 'post-weaning', 'challenge', 'pig', 'industry', 'associated', 'high', 'use', 'antibiotics', 'reduced', 'animal', 'welfare', 'depressed', 'growth', 'rate', 'exact', 'etiology', 'ccd', 'still', 'unclear', 'however', 'pathogens', 'including', 'brachyspira', 'b', 'hyodysenteriae', 'b', 'pilosicoli', 'swine', 'whipworms', 'trichuris', 'suis', 'involved', 'specific', 'colitis', 'sc', 'absence', 'specific', 'pathogens', 'dietary', 'factors', 'high', 'levels', 'protein', 'pelleted', 'feedstuffs', 'lack', 'sufficient', 'antioxidants', 'result', 'non-specific', 'colitis', 'nsc', 'hand', 'supplement', 'polyunsaturated', 'fatty', 'acids', 'pufa', 'polyphenols', 'sufficient', 'supply', 'essential', 'amino', 'acids', 'e.g', 'threonine', 'cysteine', 'proline', 'short-chain', 'fatty', 'acids', 'scfa', 'especially', 'butyrate', 'resistant', 'starch', 'shown', 'confer', 'preventing/ameliorating', 'effects', 'ccd', 'different', 'putative', 'biomarkers', 'associated', 'ccd', 'presented', 'anticipated', 'comprehensive', 'picture', 'possible', 'causes', 'ccd', 'potential', 'dietary', 'interventions', 'could', 'cast', 'light', 'direction', 'future', 'studies', 'aimed', 'developing', 'preventive', 'curative', 'strategies', 'ccd', 'growing', 'pigs']
#
# Diversity and burden of helminthiasis in wild ruminants in Iran.
# ['paper', 'aimed', 'investigate', 'diversity', 'burden', 'helminthiasis', 'ovis', 'orientalis', 'n', '26', 'capra', 'aegagrus', 'n', '29', 'gazella', 'subgutturosa', 'n', '24', 'grazed', '37', 'national', 'parks', '9', 'provinces', 'iran', 'organs', 'body', 'cavities', 'infected', 'helminths', 'included', 'gastrointestinal', 'tract', 'peritoneal', 'cavity', 'heart', 'liver', 'lungs', 'contents', 'extracted', 'washed', 'running', 'water', 'intestinal', 'lung-isolated', 'nematodes', 'cleared', 'lactophenol', 'subsequently', 'fixed', 'cestodes', 'stained', 'alum', 'carmine', 'mounted', 'en', 'face', 'berleses', 'fluid', 'slight', 'pressure', 'microscopic', 'slide', 'cover', 'slip', 'helminth', 'species', 'identified', 'study', 'include', 'intestinal', 'nematodes', 'marshallagia', 'marshalli', 'teladorsagia', 'circumcincta', 'ostertagia', 'ostertagi', 'nematodirus', 'oiratianus', 'nematodirella', 'longispiculata', 'skrjabinema', 'ovis', 'trichuris', 'ovis', 'trichuris', 'discolor', 'parabronema', 'skrjabini', 'lungworms', 'protostrongylus', 'rufescens', 'cystocaulus', 'ocreatus', 'adult', 'cestodes', 'moniezia', 'expansa', 'helicometra', 'giardi', 'avitellina', 'centripunctata', 'stilesia', 'globipunctata', 'metacestodes', 'cysticercus', 'spp', 'hydatid', 'cyst', 'cysticercus', 'tenuicollis', 'proportion', 'different', 'helminth', 'species', 'ranged', 'low', 'moderate', '3.45-46.15', 'intensity', 'helminth', 'isolation', 'different', 'ruminants', 'ranged', '2', '20', 'taxa', 'identified', 'study', 'reported', 'wild', 'animal', 'species', 'around', 'world', 'presence', 'cysticercus', 'spp', 'cardiac', 'involvement', 'g', 'subgutturosa', 'helminths', 'c', 'aegagrus', 'reported', 'first', 'time', 'iran', 'significant', 'reduction', 'observed', 'worm', 'burden', 'compared', 'previous', 'studies', 'iran', 'indicating', 'changes', 'wildlife', 'host-parasite', 'systems', 'linked', 'many', 'reasons', 'including', 'climate', 'changes', 'public', 'health', 'policies', 'e.g', 'strategic', 'anthelmintic', 'use', 'domestic', 'ruminants', 'anthropogenic', 'factors', 'environmental', 'changes', 'e.g', 'urbanization', 'agricultural', 'expansion', 'physical', 'barriers', 'well', 'vegetation', 'growth', 'host', 'availability']
#
# Occurrence of Endoparasites in Adult Swedish Dogs: A Coprological Investigation.
# ['occurrence', 'endoparasites', 'swedish', 'adult', 'dogs', 'n', '303', 'investigated', 'january', 'october', '2014', 'included', 'dogs', 'clinically', 'healthy', 'older', '1', 'year', 'untreated', 'anthelmintics', 'endectocides', 'least', '3', 'months', 'prior', 'sampling', 'grouped', 'according', 'age', 'category', 'dog', 'time', 'since', 'last', 'antiparasitic', 'treatment', 'samples', 'analyzed', 'flotation', 'detect', 'parasitic', 'eggs', 'cysts/oocysts', 'among', '129', '43', 'dogs', 'also', 'analyzed', 'baermann-technique', 'detect', 'cardiopulmonary', 'larval', 'stages', 'parasite', 'dispersal', 'stages', 'found', '24', '7.9', 'ci', '95', '4.9-10.1', 'dogs', 'flotation', 'dog', 'shed', 'cardiopulmonary', 'larval', 'stages', 'giardia', 'sp', 'cysts', 'observed', '2.6', 'n', '8', 'dogs', 'examined', 'cysts', 'sarcocystis', 'spp', 'observed', '0.6', 'n', '2', 'oocysts', 'cystosisopora', 'ohioensis', 'found', 'one', 'dog', '0.3', 'eggs', 'toxocara', 'canis', '2.3', 'n', '7', 'uncinaria', 'stenocephala', '1.3', 'n', '4', 'trichuris', 'vulpis', '0.3', 'one', 'dog', 'found', 'none', 'dogs', 'diagnosed', 'one', 'species', 'although', 'occurrence', 'endoparasites', 'average', 'dogs', '≤', '2', 'years', 'age', '11.5', 'nematodes', 'common', 'older', 'dogs', '≥4', 'years', '77.0', 'although', 'occurrence', 'lower', 'working/exhibition', 'dogs', '5.9', 'companion', 'dogs', '8.4', 'hunting-dogs', '8.6', 'differences', 'significant', 'however', 'dogs', 'exposed', 'prey', 'according', 'owner', 'statistically', 'significant', 'higher', 'prevalence', 'dogs', '20.5', 'vs', '5.7', 'odds', 'ratio', '4.0', 'ci', '95', '1.58-10.11', 'dogs', 'access', 'prey', '2.4', 'ci', '95', '0.37-8.06', 'dogs', 'staying', 'day-care', '2', 'ci', '95', '0.96-5.96', 'bitches', 'furthermore', 'significant', 'association', 'observed', 'infection', 'nematodes', 'exposures', 'prey', 'p', '0.006', 'reference', 'data', 'endoparasites', 'canine', 'fecal', 'samples', 'submitted', 'national', 'veterinary', 'institute', 'sva', 'uppsala', '2014', 'presented', 'overall', 'study', 'shows', 'low', 'occurrence', 'endoparasites', 'among', 'dogs', 'sweden', 'risk-assessment', 'zoonotic', 'parasites', 'well', 'deworming', 'recommendations', 'take', 'advantage', 'updated', 'figures']
#
# First isolation of Trichuris from wild blue sheep (Pseudois nayaur) in the Helan Mountains, China.
# ['four', 'adult', 'female', 'worms', 'trichuris', 'isolated', 'individual', 'wild', 'blue', 'sheep', 'pseudois', 'nayaur', 'inhabiting', 'helan', 'mountains', 'china', 'epidemiological', 'survey', 'wild', 'ruminant', 'although', 'differences', 'among', 'worms', 'posterior', 'end', 'rectum', 'morphology', 'egg', 'shape', 'little', 'information', 'regarding', 'species', 'status', 'could', 'inferred', 'morphology', 'phylogenetic', 'trees', 'constructed', 'based', 'sequences', 'its1', 'segment', 'ribosomal', 'rna', 'rrna', 'sequences', 'four', 'trichuris', 'specimens', 'wild', 'blue', 'sheep', 'divided', 'two', 'distinct', 'lineages', 'clade', 'clade', 'b', 'two', 'specimens', 'clade', 'named', 'genotype', 'closest', 'relationship', 'trichuris', 'skrjabini', 'two', 'specimens', 'clade', 'b', 'named', 'genotype', 'ii', 'closest', 'genetic', 'relationship', 'previously', 'described', 'trichuris', 'sp', 'two', 'trichuris', 'genotypes', 'identified', 'present', 'study', '18s', 'fragments', '261', '262', 'bp', 'newly', 'obtained', 'sequences', 'found', 'highly', 'conserved', 'merely', 'one', 'insert', 'mutation', 'single', 'nucleotide', 'present', 'genetic', 'distance', 'based', 'its1', 'members', 'clade', 'composed', 'two', 'skrjabini', 'individuals', 'two', 'genotype', 'individuals', 'ranged', '0', '0.0034', 'distances', 'within', 'intraspecies', 'variation', 'trichuris', '0-0.0272', 'suggesting', 'genotype', 'individuals', 'infesting', 'wild', 'blue', 'sheep', 'skrjabini', 'clade', 'b', 'newly', 'obtained', 'sequences', 'clustered', 'trichuris', 'sp', 'specimens', 'isolated', 'ruminants', 'sheep', 'black', 'goat', 'strong', 'support', 'genetic', 'distance', 'ranged', '0.0068', '0.017', 'also', 'within', 'intraspecies', 'variation', 'trichuris', '0-0.0272', 'however', 'genetic', 'distances', 'clade', 'clade', 'b', '0.0442', '0.0578', 'higher', 'intraspecies', 'distances', 'trichuris', 'lower', 'interspecies', 'distances', '0.102-0.5078', 'results', 'implied', 'clade', 'clade', 'b', 'likely', 'represent', 'two', 'subpopulations', 'skrjabini', 'however', 'possibility', 'clade', 'skrjabini', 'clade', 'b', 'candidatus', 'trichuris', 'could', 'excluded']
#
# Case report: Control of intestinal nematodes in captive Chlorocebus sabaeus.
# ['limited', 'data', 'efficacy', 'antiparasitic', 'treatments', 'husbandry', 'methods', 'control', 'nematode', 'infections', 'captive', 'populations', 'african', 'green', 'monkeys', 'agms', 'chlorocebus', 'sabaeus', 'faecal', 'egg', 'count', 'fec', 'tests', '10', '11', '91', 'adult', 'male', 'agms', 'captured', 'large', 'feral', 'population', 'island', 'st', 'kitts', 'evidence', 'nematode', 'infections', 'mostly', 'capillaria', '8/11', '73', 'trichuris', 'trichiura', '7/11', '64', 'strongylid', 'species', '7/11', '64', 'specifically', 'hookworm', 'trichostrongylus', '50/50', 'also', 'strongyloides', 'fuelleborni', '1/11', '9', 'kept', 'individual', 'cages', 'cleaning', 'feeding', 'regimens', 'prevent', 'reinfections', 'treated', 'concurrently', 'ivermectin', '300', 'µg/kg', 'given', 'subcutaneously', 'albendazole', '10', 'mg/kg', 'given', 'orally', 'daily', '3', 'days', '60', '6/10', 'agms', 'negative', 'follow-up', 'fec', '3', 'months', 'fec', 'necropsy', 'end', 'study', '5-8', 'months', 'later', 'one', 'monkey', 'appeared', 'reinfected', 'trichiura', 'negative', 'fec', '3', 'months', 'post-treatment', 'four', 'agms', 'positive', 'trichiura', '3', 'month', 'fec', 'follow-up', 'negative', 'end', 'study', 'one', 'treatment', 'regimen', 'although', 'initially', 'cleared', 'capillaria', 'following', 'treatment', 'three', 'agms', 'found', 'infected', 'end', 'study', 'ivermectin', 'albendazole', 'treatment', 'regimen', 'coupled', 'good', 'husbandry', 'practices', 'prevent', 'reinfections', 'effectively', 'controlled', 'nematode', 'infections', 'captive', 'agms']
#
# Immunoregulatory molecules secreted by Trichuris muris.
# ['trichuris', 'whipworm', 'nematode', 'infections', 'prevalent', 'humans', 'domestic', 'livestock', 'mammals', 'share', 'epithelial', 'dwelling', 'niche', 'similar', 'life', 'cycle', 'chronic', 'infections', 'follow', 'implying', 'immune', 'evasion', 'mechanisms', 'operating', 'nematode', 'excretory', 'secretory', 'es', 'products', 'shown', 'rich', 'source', 'immunomodulatory', 'molecules', 'many', 'species', 'trichuris', 'muris', 'model', 'natural', 'parasite', 'mice', 'used', 'extensively', 'study', 'host–parasite', 'interactions', 'provides', 'tractable', 'platform', 'investigation', 'immunoregulatory', 'capacity', 'whipworm', 'es', 'present', 'review', 'details', 'progress', 'identification', 'composition', 'muris', 'es', 'immunomodulatory', 'components', 'potential', 'mechanisms', 'action', 'adult', 'muris', 'secretome', 'dominated', 'one', 'protein', 'modulatory', 'capacity', 'although', 'remains', 'completely', 'characterized', 'addition', 'secretome', 'contains', 'multiple', 'proteins', 'small', 'molecules', 'immunomodulatory', 'potential', 'certainly', 'comparison', 'trichuris', 'species', 'moreover', 'muris-derived', 'exosomes/exosome-like', 'vesicles', 'contain', 'protein', 'multiple', 'mirnas', 'providing', 'alternate', 'delivery', 'process', 'molecules', 'potential', 'modulate', 'host', 'immunity']
#
# The prevalence of intestinal nematodes among red foxes (Vulpes vulpes) in north-western Poland.
# ['red', 'fox', 'vulpes', 'vulpes', 'widely', 'distributed', 'northern', 'hemisphere', 'australia', 'presence', 'nematode-infected', 'foxes', 'urbanized', 'areas', 'increases', 'risk', 'transmission', 'nematodes', 'domestic', 'dogs', 'thus', 'humans', 'aim', 'study', 'determine', 'prevalence', 'species', 'composition', 'intestinal', 'nematodiasis', 'red', 'foxes', 'western', 'pomerania', 'province', 'north-western', 'poland', 'intestinal', 'contents', '620', 'red', 'foxes', 'killed', 'government', 'reduction', 'shooting', 'programme', 'examined', 'adult', 'nematodes', 'using', 'sedimentation', 'counting', 'technique', 'sct', 'intestinal', 'nematodes', 'including', 'toxocara', 'canis', 'toxascaris', 'leonina', 'uncinaria', 'stenocephala', 'trichuris', 'vulpis', 'found', '77.3', '95', 'ci', '73.8-80.4', 'examined', 'foxes', 'mean', 'infection', 'burden', '20.1', 'nematode', 'per', 'animal', 'male', 'female', 'foxes', 'similar', 'infection', 'burdens', 'nematodes', 'present', 'high', 'prevalence', 'intensity', 'among', 'foxes', 'north-western', 'poland', 'furthermore', 'high', 'prevalence', 'nematodes', 'foxes', 'may', 'likely', 'constitute', 'health', 'risk', 'humans', 'domestic', 'animals', 'due', 'increasing', 'fox', 'densities', 'urban', 'periurban', 'areas']
#
# Prevalence of intestinal parasites in dogs from public shelters in Serbia.
# ['data', 'endoparasitic', 'infections', 'dogs', 'dog', 'shelters', 'southeastern', 'europe', 'limited', 'thus', 'study', 'aimed', 'add', 'existing', 'knowledge', 'topic', 'reporting', 'prevalence', 'intestinal', 'parasites', 'dogs', 'public', 'dog', 'shelters', 'republic', 'serbia', '2017', '2018', 'individual', 'pooled', 'fecal', 'samples', 'collected', '1267', 'dogs', 'six', 'shelters', 'samples', 'qualitatively', 'examined', 'parasites', 'using', 'flotation', 'tests', 'seven', 'taxa', 'intestinal', 'parasites', 'identified', 'cystoisospora', 'spp', 'ascarids', 'toxocara', 'canis', 'toxascaris', 'leonina', 'hookworms', 'trichuris', 'vulpis', 'taeniids', 'dipylidium', 'caninum', 'overall', 'prevalence', 'intestinal', 'parasites', '58', '3', '78', '1', 'young', 'dogs', '53.1', 'adult', 'dogs', 'parasites', 'detected', 'young', '1', 'year', 'old', 'adult', 'dogs', '1', 'year', 'old', 'cystoisospora', 'spp', '20', '4.9', 'canis', '33.5', '14.7', 'leonina', '7.7', '2.3', 'hookworms', '16.9', '15', 'respectively', 'however', 'vulpis', '9.6', 'taeniids', '1.3', 'caninum', '5.4', 'detected', 'adult', 'dogs', 'belgrade', 'shelter', 'young', 'dogs', 'higher', 'prevalence', 'endoparasitic', 'infections', '18.9', '49/260', 'adult', 'dogs', '14.8', '149/1007', 'subotica', 'jagodina', 'niš', 'shelters', 'young', 'dogs', 'significantly', 'higher', 'p', '0.001', 'p', '0.05', 'respectively', 'prevalence', 'endoparasitic', 'infections', '10', '12.3', '14.6', 'adult', 'dogs', '5.3', '8', '7.2', 'results', 'useful', 'establishing', 'health', 'care', 'programs', 'dog', 'shelters', 'implementing', 'effective', 'strategies', 'control', 'intestinal', 'parasites']
#
# Lungworms (Metastrongylus spp.) and intestinal parasitic stages of two separated Swiss wild boar populations north and south of the Alps: Similar parasite spectrum with regional idiosyncrasies.
# ['metastrongylus', 'sp', 'lungworm', 'worldwide', 'distribution', 'wild', 'boars', 'suids', 'switzerland', 'two', 'wild', 'boar', 'populations', 'geographically', 'divided', 'alps', 'investigated', '84', 'wild', 'boars', '52', 'north', '32', 'south', 'alps', 'different', 'sex', 'age', 'juveniles', 'subadults', 'adults', 'shot', 'september', 'december', '2018', 'lungs', 'macroscopically', 'examined', 'dissected', 'detection', 'metastrongylus', 'specimens', 'additionally', 'faecal', 'samples', 'obtained', '55', 'animals', 'analysed', 'sedimentation/flotation', 'mini-flotac®', 'method', 'overall', '12774', 'metastrongylus', 'sp', 'specimens', 'isolated', 'prevalence', '77.4', 'mean', 'burden', '196.5', 'range', '1-2589', 'significant', 'differences', 'north', '80.8', '218.0', 'south', '71.9', '157.4', 'sexes', 'age', 'groups', 'macroscopically', 'dense', 'nodular', 'lesions', 'associated', 'metastrongylus', 'sp', 'present', '19', '65', '33.9', 'positive', 'lungs', 'five', 'metastrongylus', 'sp', 'detected', 'pudendotectus', '67.9', 'salmi', '63.1', 'confusus', '56', 'apri', '44', 'asymmetricus', '17.9', 'significant', 'difference', 'p', '0.012', 'north', '32.7', 'south', '62.5', 'apri', 'lungworm', 'population', 'female', 'biased', 'number', 'metastrongylus', 'sp', 'eggs', 'faecal', 'samples', 'correlate', 'worm', 'burdens', 'furthermore', 'following', 'endoparasites', 'detected', 'isospora', 'suis/eimeria', 'sp', '74.5', 'strongyloides', 'suis', '27.3', 'trichuris', 'suis', '20.0', 'hyostrongylus', 'rubidus/oesophagostomum', 'sp', '18.2', 'globocephalus', 'sp', '9.1', 'capillaria', 'sp', '7.3', 'ascaris', 'suum', '3.6', 'giardia', 'sp', '3.6', 'balantidium', 'coli', '1.8', 'significant', 'differences', 'suis', 'north', '36.1', 'south', '10.5', 'globocephalus', 'sp', 'south', '26.3', 'although', 'geographically', 'separated', 'swiss', 'wild', 'boar', 'populations', 'share', 'similar', 'parasite', 'spectra', 'also', 'showing', 'regional', 'idiosyncrasies', 'partially', 'explained', 'ecological', 'climatic', 'factors', 'despite', 'clinical', 'relevance', 'unknown', 'accurate', 'knowledge', 'concerning', 'distribution', 'endoparasites', 'wildlife', 'reservoir', 'relevant', 'better', 'understand', 'risk', 'factors', 'domestic', 'pig', 'population']
#
# A 3-year retrospective analysis of canine intestinal parasites: fecal testing positivity by age, U.S. geographical region and reason for veterinary visit.
# ['canine', 'life', 'stage', 'key', 'factor', 'parasite', 'prevalence', 'clinical', 'signs', 'associated', 'parasitism', 'common', 'pups', 'adult', 'dogs', 'health', 'status', 'geographical', 'region', 'may', 'also', 'play', 'role', 'parasite', 'prevalence', 'purpose', 'study', 'evaluate', 'fecal', 'test', 'results', 'using', 'zinc', 'sulfate', 'flotation', 'centrifugation', 'combined', 'fecal', 'antigen', 'testing', 'hookworms', 'ancylostoma', 'spp', 'uncinaria', 'stenocephala', 'ascarids', 'toxocara', 'canis', 'toxascaris', 'spp', 'baylisascaris', 'spp', 'whipworms', 'trichuris', 'vulpis', 'sorted', 'age', 'geographical', 'region', 'veterinary', 'visit', 'type', 'retrospective', 'sample', 'intestinal', 'parasite', 'panels', 'submitted', 'idexx', 'laboratories', '1,626,104', 'individual', 'dogs', 'selected', 'continental', 'usa', '1', 'january', '2017', '31', 'december', '2019', 'data', 'contain', 'results', 'fecal', 'exams', 'performed', 'using', 'zinc', 'sulfate', 'flotation', 'centrifugation', 'paired', 'coproantigen', 'immunoassay', 'results', 'hookworms', 'ascarids', 'whipworms', 'giardia', 'fecal', 'dx®', 'giardia', 'coproantigen', 'immunoassay', 'plate', 'paired', 'testing', 'either', 'coproantigen', 'assay', 'flotation', 'test', 'positive', 'sample', 'considered', 'positive', 'data', 'summarized', 'age', 'category', 'u.s', 'census', 'bureau', 'geographical', 'region', 'northeast', 'south', 'midwest', 'west', 'veterinary', 'visit', 'type', 'visit', 'types', 'subdivided', 'wellness', 'visits', 'clinical', 'visits', 'fecal', 'sample', 'submitted', 'dogs', 'presenting', 'either', 'wellness', 'visits', 'clinical', 'visits', 'giardia', 'testing', 'included', 'giardia', 'highest', 'positivity', 'combined', 'results', 'microscopy', 'coproantigen', '12.2', '10.8', 'respectively', 'followed', 'hookworms', 'combined', 'microscopy', 'coproantigen', '4.1', '4.2', 'respectively', 'ascarids', 'combined', 'microscopy', 'coproantigen', '2.5', '1.7', 'respectively', 'whipworms', 'combined', 'microscopy', 'coproantigen', '1.1', '1.4', 'respectively', 'test', 'results', 'pooled', 'together', 'pups', 'aged', '2-6', 'months', 'observed', 'highest', 'proportion', 'positive', 'results', 'either', 'microscopy', 'coproantigen', 'immunoassay', 'regardless', 'clinical', 'visit', 'type', 'parasite', 'positivity', 'varied', 'geographical', 'region', 'regardless', 'visit', 'type', 'age', 'geographical', 'region', 'coproantigen', 'method', 'observed', 'find', 'higher', 'proportion', 'positive', 'test', 'results', 'microscopy', 'giardia', 'ascarids', 'hookworms', 'whipworms', 'fecal', 'dx®', 'coproantigen', 'immunoassay', 'combined', 'zinc', 'sulfate', 'flotation', 'centrifugation', 'method', 'uncovers', 'higher', 'number', 'positive', 'hookworm', 'ascarid', 'whipworm', 'infections', 'zinc', 'sulfate', 'flotation', 'alone', 'pups', 'adult', 'dogs', 'across', 'geographical', 'regions', 'usa', 'regardless', 'visit', 'type']
#
# Detection of heartworm antigen without cross-reactivity to helminths and protozoa following heat treatment of canine serum.
# ['detection', 'dirofilaria', 'immitis', 'heartworm', 'antigen', 'sera', 'primary', 'means', 'diagnosing', 'infections', 'dogs', 'recent', 'years', 'practice', 'heat-treating', 'serum', 'prior', 'antigen', 'testing', 'demonstrated', 'improved', 'detection', 'heartworm', 'infection', 'practice', 'heat-treating', 'serum', 'resulted', 'earlier', 'detection', 'improved', 'sensitivity', 'heartworm', 'infections', 'suggested', 'heat', 'treatment', 'may', 'cause', 'cross', 'reactivity', 'reconditum', 'intestinal', 'helminth', 'infections', 'dogs', 'studies', 'assessed', 'potential', 'cross-reactivity', 'parasites', 'heartworm', 'tests', 'heat', 'treatment', 'using', 'blood', 'products', 'appropriate', 'gold', 'standard', 'reference', 'canine', 'sera', 'n163', 'used', 'evaluate', 'heartworm', 'antigen-elisa', 'dirochek®', 'potential', 'cross-reactivity', 'common', 'parasitic', 'infections', 'heartworm', 'status', 'additional', 'parasite', 'infections', 'confirmed', 'necropsy', 'adult', 'helminth', 'species', 'verified', 'morphologically', 'pcr', 'feces', 'evaluated', 'centrifugal', 'fecal', 'flotation', 'intestinal', 'parasites', 'confirmed', '140', 'dogs', 'necropsy', '130', 'fecal', 'flotation', 'acanthocheilonema', 'reconditum', 'microfilariae', 'confirmed', '22', 'dogs', 'prevalence', 'heartworm', 'infection', 'confirmed', 'necropsy', '35.6', '58/163', '105', 'dogs', 'without', 'heartworms', 'specificity', 'remained', 'unchanged', '100', 'heat', 'treatment', 'despite', 'confirmed', 'infections', 'reconditum', 'ancylostoma', 'caninum', 'ancylostoma', 'brasiliense', 'trichuris', 'vulpis', 'toxocara', 'canis', 'dipylidium', 'caninum', 'spirometra', 'mansonoides', 'macracanthorynchus', 'ingens', 'cystoisospora', 'sp', 'giardia', 'sp', 'sarcocystis', 'sp', 'findings', 'suggest', 'use', 'heat', 'treatment', 'improves', 'sensitivity', 'heartworm', 'tests', 'unlikely', 'cause', 'false', 'positive', 'antigen', 'results', 'due', 'acanthocheilonema', 'reconditum', 'intestinal', 'helminths', 'protozoal', 'parasites', 'dogs']
#
# High prevalence of Clonorchis sinensis infection in Guangxi, Southern China.
# ['soil-transmitted', 'helminths', 'sths', 'hookworm', 'roundworm', 'whipworm', 'food-borne', 'trematodiases', 'including', 'clonorchis', 'sinensis', 'remain', 'public', 'health', 'problem', 'worldwide', 'especially', 'tropical', 'subtropical', 'regions', 'aimed', 'determine', 'current', 'prevalence', 'parasites', 'guangxi', 'china', 'located', 'subtropical', 'region', 'cross-sectional', 'study', '4-year', 'longitudinal', 'surveillance', 'study', 'carried', 'stool', 'samples', 'collected', 'examined', 'microscopically', 'parasite', 'eggs', 'using', 'modified', 'kato-katz', 'thick', 'smear', 'method', 'study', 'subjects', 'selected', 'using', 'stratified', 'random', 'cluster', 'sampling', 'cross-sectional', 'study', 'longitudinal', 'surveillance', 'study', 'numbered', '15,683', '24,429', 'respectively', 'cross-sectional', 'study', 'hookworm', 'roundworm', 'whipworm', 'pinworm', 'c', 'sinensis', 'tapeworm', 'found', 'total', 'prevalence', 'soil-transmitted', 'helminths', 'sths', '6.4', '95', 'ci', '6.0-6.8', 'prevalences', 'c', 'sinensis', 'hookworm', 'roundworm', 'whipworm', 'pinworm', '10.6', '4.2', '0.3', '0.3', '1.8', 'respectively', 'prevalence', 'c', 'sinensis', 'males', '14.0', '95', 'ci', '13.3-14.8', 'significantly', 'higher', 'females', '7.2', '95', 'ci', '6.7-7.8', 'p', '0.0001', 'prevalence', 'also', 'significantly', 'higher', 'medical', 'worker', 'group', '20.8', '95', 'ci', '12.9-28.7', 'occupational', 'groups', '10.5', '95', 'ci', '10.0-11.0', 'p', '0.0001', 'prevalence', 'hookworm', 'females', '5.3', '95', 'ci', '4.8-5.8', 'significantly', 'higher', 'males', '3.0', '95', 'ci', '2.6-3.3', 'p', '0.0001', 'longitudinal', 'surveillance', 'study', 'prevalence', 'c', 'sinensis', 'sths', '2016', '2017', '2018', '2019', '12.0', '6.0', '11.0', '10.0', '2.6', '2.8', '1.5', '1.5', 'respectively', 'adult', 'male', 'occupation', 'medical', 'workers', 'risk', 'factors', 'infection', 'c', 'sinensis', 'hookworm', 'prevalence', 'rate', 'c', 'sinensis', 'remains', 'high', 'sths', 'decreasing', 'suggesting', 'enhanced', 'health', 'education', 'focused', 'c', 'sinensis', 'guangxi']
#
# Evaluation of Commercially Available Anthelminthics in Laboratory Models of Human Intestinal Nematode Infections.
# ...
#
# Prevalence of Intestinal Parasites and Associated Risk Factors for Infection among Rural Communities of Chachoengsao Province, Thailand.
# ['intestinal', 'parasitic', 'infections', 'remain', 'major', 'public', 'health', 'problem', 'many', 'parts', 'thailand', 'particularly', 'rural', 'areas', 'study', 'aimed', 'determine', 'prevalence', 'intestinal', 'parasitic', 'infections', 'associated', 'risk', 'factors', 'among', 'people', 'living', 'huai', 'sai', 'sub-district', 'bang', 'khla', 'district', 'chachoengsao', 'province', 'central', 'thailand', 'cross-sectional', 'survey', 'carried', 'june', '2017', 'august', '2017', 'included', 'total', '224', 'participants', 'stool', 'samples', 'examined', 'using', 'simple', 'direct', 'smear', 'formalin', 'ethyl', 'acetate', 'concentration', 'technique', 'association', 'risk', 'factors', 'intestinal', 'parasitic', 'infections', 'assessed', 'using', 'multivariate', 'logistic', 'regression', 'analysis', 'overall', 'prevalence', 'intestinal', 'parasitic', 'infections', '16.1', 'soil-transmitted', 'helminth', 'infections', '14.3', 'common', 'protozoan', 'infections', '1.8', 'common', 'intestinal', 'parasites', 'hookworms', '6.7', 'followed', 'strongyloides', 'stercoralis', '5.0', 'ascaris', 'lumbricoides', '1.3', 'trichuris', 'trichiura', '1.3', 'entamoeba', 'histolytica/dispar', '1.0', 'giardia', 'intestinalis', '0.4', 'blastocystis', 'hominis', '0.4', 'protozoans', 'identified', 'high', 'prevalence', 'infections', 'found', 'male', 'participants', '≥40', 'years', 'raised', 'dogs', 'households', 'wear', 'boots', 'working', 'fields', 'multivariate', 'analysis', 'showed', 'significant', 'association', 'intestinal', 'parasitic', 'infections', 'gender', 'adjusted', 'odds', 'ratio', '2.4', '95', 'confidence', 'interval', 'ci', '1.1-5.2', 'p0.020', 'results', 'showed', 'high', 'prevalence', 'soil-transmitted', 'helminth', 'infections', 'among', 'adults', 'rural', 'communities', 'particularly', 'apparent', 'regarding', 'skin-penetrating', 'species', 'nematodes', 'greater', 'focus', 'intervention', 'required', 'improving', 'sanitation', 'personal', 'hygiene', 'prevent', 'spread', 'intestinal', 'parasitic', 'infections']
#
# The optimal timing of post-treatment sampling for the assessment of anthelminthic drug efficacy against Ascaris infections in humans.
# ['egg', 'reduction', 'rate', 'err', 'current', 'standard', 'mean', 'assess', 'efficacy', 'drugs', 'human', 'soil-transmitted', 'helminths', 'sths', 'ascaris', 'lumbricoides', 'trichuris', 'trichiura', 'hookworm', 'although', 'timing', 'post-treatment', 'sampling', 'pivotal', 'readily', 'interpretation', 'drug', 'efficacy', 'lack', 'empirical', 'data', 'allows', 'recommending', 'optimal', 'time', 'point', 'follow-up', 'egg', 'counting', 'present', 'study', 're-analyzed', 'kinetics', 'worm', 'expulsion', 'egg', 'output', 'ascaris', 'lumbricoides', 'following', 'single', 'oral', 'dose', 'albendazole', 'series', 'studies', 'previously', 'conducted', 'kenyan', 'communities', 'results', 'indicate', 'takes', '10', 'days', 'post-treatment', 'expulsion', 'adult', 'male', 'female', 'ascaris', 'worms', 'completed', 'approximately', '20', 'worms', 'expelled', 'day', '7', '10', 'post-treatment', 'sequential', 'analysis', 'egg', 'put', 'indicated', 'poor', 'err', '89.4', 'day', '7', 'post-treatment', '100', 'err', 'day', '14', '21', 'post-treatment', 'based', 'findings', 'recommend', 'wait', 'least', '14', 'days', 'albendazole', 'treatment', 'conducting', 'follow-up', 'egg', 'count', 'sampling', 'time', 'point', 'may', 'result', 'biased', 'err', 'estimates', 'due', 'release', 'residual', 'eggs', 'moribund', 'degenerating', 'worms']
#
# Helminth Infections of Rodents and Their Zoonotic Importance in Boyer-Ahmad District, Southwestern Iran.
# ['rodents', 'considered', 'reservoirs', 'various', 'zoonotic', 'diseases', 'including', 'helminthic', 'infections', 'current', 'study', 'aimed', 'evaluate', 'prevalence', 'helminth', 'infections', 'rodents', 'boyer-ahmad', 'district', 'southwestern', 'iran', 'overall', '52', 'rodents', 'captured', 'various', 'areas', 'district', 'sherman', 'live', 'traps', 'animals', 'euthanized', 'dissected', 'necropsy', 'organ', 'examined', 'macroscopically', 'presence', 'cyst', 'visible', 'parasite', 'gastrointestinal', 'tract', 'removed', 'contents', 'evaluated', 'larva', 'adult', 'worms', 'trichinella', 'larvae', 'rodents', 'muscles', 'investigated', 'digestion', 'pathological', 'methods', 'twenty-eight', '53.8', 'trapped', 'rodents', 'male', 'rodents', 'including', '25', '48.1', 'meriones', 'persicus', '11.9', 'calomyscus', 'bailwardi', '1', '1.9', 'arvicola', 'terresterris', '7', '13.5', 'rattus', 'rattus', '8', '15.4', 'r', 'norvegicus', '10', '19.2', 'apodemus', 'sylvaticus', '38', '73.0', 'infected', 'least', 'one', 'helminth', 'collected', 'rodents', 'infected', 'hymenolepis', 'diminuta', '50', 'hymenolepis', 'nana', 'fraterna', '28.8', 'skrjabinotaenia', 'sp', '15.4', 'anoplocephalidae', 'sp', '15.4', 'cysticercus', 'fasciolaris', '5.8', 'trichuris', 'muris', '36.5', 'aspiculuris', 'tetraptera', '15.4', 'syphacia', 'sp', '5.7', 'rictularia', 'sp', '15.4', 'trichostrongylus', 'sp', '3.8', 'gongylonema', 'sp', '3.8', 'persicus', '84', 'infected', 'rodent', 'yet', 'differences', 'rodent', 'genus', 'helminth', 'infectivity', 'statistically', 'significant', 'p0.05', 'rodents', 'boyer-ahmad', 'district', 'infected', 'different', 'helminths', 'infections', 'recognized', 'threat', 'human', 'health']
#
# Polypyridylruthenium(II) complexes exert in vitro and in vivo nematocidal activity and show significant inhibition of parasite acetylcholinesterases.
# ['4.5', 'billion', 'people', 'risk', 'infection', 'soil', 'transmitted', 'helminths', 'concerns', 'development', 'resistance', 'handful', 'frontline', 'nematocides', 'endemic', 'populations', 'investigated', 'anti-nematode', 'efficacy', 'series', 'polypyridylrutheniumii', 'complexes', 'showed', 'active', 'l3', 'adult', 'stages', 'trichuris', 'muris', 'rodent', 'homologue', 'causative', 'agent', 'human', 'trichuriasis', 'trichiura', 'one', 'compounds', 'rubb12-mono', 'among', 'potent', 'ability', 'kill', 'l3', 'ic50', '3.1', '±', '0.4', 'μm', 'adult', 'ic50', '5.2', '±', '0.3', 'μm', 'stage', 'worms', 'assessed', 'efficacy', 'mouse', 'model', 'trichuriasis', 'administering', '3', 'consecutive', 'daily', 'oral', 'doses', 'drug', '3', 'weeks', 'post', 'infection', 'murine', 'whipworm', 'trichuris', 'muris', 'mice', 'treated', 'rubb12-mono', 'showed', 'average', '66', 'reduction', 'p', '0.015', 'faecal', 'egg', 'count', 'two', 'independent', 'trials', 'drugs', 'partially', 'exerted', 'activity', 'inhibition', 'acetylcholinesterases', 'worms', 'treated', 'vitro', 'vivo', 'showed', 'significant', 'decreases', 'activity', 'class', 'enzymes', 'data', 'show', 'ruthenium', 'complexes', 'effective', 'muris', 'model', 'gastro-intestinal', 'nematode', 'soil-transmitted', 'helminth', 'knowledge', 'target', 'ruthenium', 'drugs', 'facilitate', 'modification', 'current', 'compounds', 'identify', 'analogues', 'even', 'effective', 'selective', 'trichuris', 'helminths', 'human', 'veterinary', 'importance']
#
# Pathway of oxfendazole from the host into the worm: Trichuris suis in pigs.
# ['well', 'known', 'efficacy', 'single', 'oral', 'dose', 'benzimidazoles', 'trichuris', 'spp', 'infections', 'humans', 'animals', 'poor', 'currently', 'still', 'used', 'control', 'programmes', 'human', 'trichuriasis', 'however', 'route', 'benzimidazoles', 'treated', 'host', 'trichuris', 'remains', 'unknown', 'parts', 'adult', 'trichuris', 'situated', 'intracellularly', 'caecum', 'might', 'exposed', 'anthelmintic', 'drugs', 'intestinal', 'content', 'well', 'mucosa', 'study', 'pathway', 'oxfendazole', 'metabolites', 'explored', 'using', 'suis-pig', 'infection', 'model', 'simultaneously', 'measuring', 'drug', 'concentrations', 'within', 'worms', 'caecal', 'mucosa', 'caecal', 'tissue', 'caecal', 'content', 'plasma', 'pigs', 'time', 'single', 'oral', 'dose', '5', 'mg/kg', 'oxfendazole', 'additionally', 'comparison', 'vivo', 'study', 'drug', 'uptake', 'metabolism', 'oxfendazole', 'suis', 'examined', 'vitro', 'incubation', 'oxfendazole', 'metabolites', 'quantified', 'high', 'performance', 'liquid', 'chromatography', 'multivariate', 'linear', 'regression', 'analysis', 'showed', 'strong', 'highly', 'significant', 'association', 'ofz', 'concentrations', 'within', 'suis', 'plasma', 'along', 'weaker', 'association', 'ofz', 'concentrations', 'caecal', 'tissue/mucosa', 'suis', 'suggesting', 'oxfendazole', 'reaches', 'suis', 'absorption', 'gastrointestinal', 'tract', 'enters', 'worms', 'blood-enterocyte', 'pathway', 'fenbendazole', 'sulfone', 'level', 'suis', 'highly', 'affected', 'concentrations', 'plasma', 'addition', 'correlations', 'drug', 'concentrations', 'host', 'compartments', 'generally', 'highest', 'metabolite', 'comparison', 'oxfendazole', 'correlation', 'plasma', 'content', 'particularly', 'high', 'metabolite', 'suggesting', 'high', 'level', 'drug', 'movement', 'compartments', 'possible', 'involvement', 'enterohepatic', 'circulation']
#
# Diagnostic strategies to reveal covert infections with intestinal helminths in dogs.
# ['intestinal', 'helminths', 'common', 'dogs', 'united', 'states', 'particularly', 'non-treated', 'dogs', 'animal', 'shelters', 'surveys', 'fecal', 'flotation', 'may', 'underestimate', 'prevalence', 'determine', 'prevalence', 'intestinal', 'helminths', 'evaluate', 'ability', 'fecal', 'flotation', 'detection', 'nematode', 'antigen', 'identify', 'infections', 'contents', 'entire', 'gastrointestinal', 'tract', '97', 'adult', '1year', 'dogs', 'previously', 'identified', 'humane', 'euthanasia', 'two', 'animal', 'control', 'shelters', 'northeastern', 'oklahoma', 'usa', 'screened', 'helminths', 'recovered', 'washed', 'saline', 'fixed', 'prior', 'enumeration', 'identification', 'genus', 'species', 'fecal', 'samples', 'dog', 'examined', 'passive', 'sodium', 'nitrate', 'sg', '1.33', 'centrifugal', 'sugar', 'solution', 'sg', '1.25', 'flotation', 'fecal', 'antigen', 'detection', 'assays', 'used', 'confirm', 'presence', 'nematode', 'antigen', 'frozen', 'fecal', 'samples', '92', 'dogs', 'necropsy', 'examination', 'revealed', 'ancylostoma', 'caninum', '45/97', '46.4', 'toxocara', 'canis', '11/97', '11.3', 'trichuris', 'vulpis', '38/97', '39.2', 'dipylidium', 'caninum', '48/97', '49.5', 'taenia', 'sp', '7/97', '7.2', 'dogs', 'passive', 'fecal', 'flotation', 'identified', '38/45', '84.4', 'caninum', '6/11', '54.5', 'canis', '26/38', '68.4', 'vulpis', '2/48', '4.2', 'caninum', '1/7', '14.3', 'taenia', 'sp', 'infections', 'centrifugal', 'flotation', 'combined', 'antigen', 'detection', 'assays', 'identified', 'caninum', '97.7', '43/44', 'canis', '77.8', '7/9', 'vulpis', '83.3', '30/36', 'infected', 'dogs', 'based', 'necropsy', 'recovery', 'nematodes', 'taken', 'together', 'data', 'indicate', 'detection', 'nematode', 'antigen', 'useful', 'adjunct', 'microscopic', 'examination', 'fecal', 'samples', 'parasite', 'eggs', 'approach', 'improve', 'diagnostic', 'sensitivity', 'intestinal', 'nematode', 'infections', 'dogs']
#
# Safety and efficacy of helminth treatment in relapsing-remitting multiple sclerosis: Results of the HINT 2 clinical trial.
# ['hygiene', 'hypothesis', 'suggests', 'microbial', 'replacement', 'may', 'therapeutic', 'allergic', 'autoimmune', 'diseases', 'nevertheless', 'results', 'helminth', 'treatment', 'including', 'multiple', 'sclerosis', 'ms', 'inconclusive', 'assess', 'safety', 'brain', 'magnetic', 'resonance', 'imaging', 'mri', 'activity', 'subjects', 'relapsing-remitting', 'multiple', 'sclerosis', 'rrms', 'oral', 'administration', 'ova', 'porcine', 'whipworm', 'trichuris', 'suis', 'tso', 'total', '16', 'disease-modifying', 'treatment', 'dmt', 'naive', 'rrms', 'subjects', 'studied', 'baseline', 'versus', 'treatment', 'bvt', 'controlled', 'prospective', 'study', 'mri', 'scans', 'performed', '5', 'months', 'screening-observation', '10', 'months', 'treatment', '4', 'months', 'post-treatment', 'surveillance', 'serious', 'symptoms', 'adverse', 'events', 'occurred', 'treatment', 'cohort', 'trend', 'consistent', '35', 'diminution', 'active', 'lesions', 'observation', 'mris', 'compared', 'treatment', 'mris', 'p', '0.08', 'level', 'individuals', '12', '16', 'subjects', 'improved', 'tso', 'treatment', 'regulatory', 'lymphocytes', 'increased', 'tso', 'treatment', 'tso', 'safe', 'rrms', 'subjects', 'potentially', 'favorable', 'mri', 'outcomes', 'immunoregulatory', 'changes', 'observed', 'tso', 'treatment', 'however', 'magnitude', 'effects', 'modest', 'considerable', 'variation', 'among', 'responses', 'individual', 'subjects']
#
# GASTROINTESTINAL PARASITIC INFECTIONS IN DEAD OR DEBILITATED MOOSE ( ALCES ALCES) IN SWEDEN.
# ['objectives', 'determine', 'prevalence', 'intensity', 'gastrointestinal', 'parasites', 'dead', 'euthanized', 'emaciated', 'moose', 'central', 'southern', 'sweden', 'n50', 'assess', 'parasite', 'intensity', 'major', 'contributing', 'factor', 'poor', 'condition', 'moose', 'animals', 'infected', 'gastrointestinal', 'nematodes', 'seven', 'parasite', 'species', 'found', 'abomasa', '10', 'species', 'found', 'small', 'intestine', 'coinfections', 'commonly', 'found', 'abomasum', 'ostertagia', 'antipini', 'mazamastrongylus', 'dagestanica', 'small', 'intestine', 'nematodirella', 'alcidis', 'trichostrongylus', 'capricola', 'moose', 'many', 'nematodes', 'highest', 'numbers', '224,400', '11,760', 'abomasum', 'small', 'intestine', 'respectively', 'fourteen', 'moose', '40,000', 'gastrointestinal', 'nematodes', 'excluding', 'large', 'intestine', 'nematodes', 'represented', 'trichuris', 'spp', 'oesophagostomum', 'venulosum', 'additionally', 'moderate', 'prevalence', '36', 'protostrongylid', 'larvae', 'dorsal', 'spine', 'larvae', 'low', 'prevalence', '2-4', 'protozoal', 'infections', 'identified', 'microscopic', 'examination', 'feces', 'adult', 'moose', 'significantly', 'parasites', 'subadults', 'results', 'show', 'parasite', 'load', 'single', 'major', 'cause', 'moose', 'mortality', 'provided', 'update', 'species', 'composition', 'helminth', 'parasites', 'moose', 'sweden', 'illustrated', 'extreme', 'infection', 'intensities', 'free-ranging', 'moose']
#
# Isothermal diagnostic assays for the detection of soil-transmitted helminths based on the SmartAmp2 method.
# ['diagnosis', 'soil-transmitted', 'helminths', 'sths', 'traditionally', 'relied', 'stool', 'microscopy', 'number', 'critical', 'deficiencies', 'molecular', 'diagnostics', 'powerful', 'tools', 'identify', 'closely', 'related', 'species', 'requirement', 'costly', 'equipment', 'makes', 'implementation', 'difficult', 'low-resource', 'field', 'settings', 'rapid', 'sensitive', 'cost-effective', 'diagnostic', 'tools', 'crucial', 'accurate', 'estimation', 'sth', 'infection', 'intensity', 'mda', 'programmes', 'goal', 'reduce', 'morbidity', 'following', 'repeated', 'rounds', 'chemotherapy', 'study', 'colourimetric', 'isothermal', 'assays', 'developed', 'using', 'smartamp2', 'primer', 'sets', 'reagents', 'loop-mediated', 'amplification', 'lamp', 'assays', 'species-specific', 'primer', 'sets', 'designed', 'specific', 'target', 'sequence', 'β-tubulin', 'gene', 'used', 'identify', 'necator', 'americanus', 'trichuris', 'trichiura', 'ascaris', 'lumbricoides', 'initial', 'optimization', 'control', 'plasmids', 'genomic', 'dna', 'adult', 'worms', 'assays', 'evaluated', 'field', 'samples', 'assays', 'showed', 'high', 'sensitivity', 'demonstrated', 'high', 'tolerance', 'inhibitors', 'spiked', 'faecal', 'samples', 'rapid', 'sensitive', 'colourimetric', 'assays', 'successfully', 'developed', 'identify', 'sths', 'field', 'samples', 'using', 'hydroxy', 'napthol', 'blue', 'hnb', 'dye', 'rapid', 'simple', 'colourimetric', 'diagnostic', 'assays', 'using', 'smartamp2', 'method', 'developed', 'potential', 'applied', 'field', 'detection', 'sth', 'infections', 'estimation', 'response', 'treatment', 'however', 'validation', 'large', 'numbers', 'field', 'samples', 'needed']

# %% [markdown]
# ### Analyzing Words Data
#
# Further analysis depends mostly on what one wants to do with the collected data.
#
# For example, this might include building profiles for each search term, based on
# data in collected articles. It might also include using methods from natural language
# processing, such as vector embeddings and/or similarity measures.
#
# Specific analyses might also be interested in exploring historical patterns in the literature,
# examining, for example, the history of when certain topics were written about, and in what
# journals, by which authors.
